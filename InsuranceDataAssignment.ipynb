# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakira25/MyData/blob/main/InsuranceDataAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Shakira25/MyData.git
# Out:
# Cloning into 'MyData'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 52 (delta 24), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (52/52), done.

# %%
# %cd MyData
# Out:
# /content/MyData

# %%
! ls
# Out:
# insurance.csv	     NK1.py	SalesData.py
# InsuranceData.ipynb  README.md	SalesFunctionAssignment.ipynb
# Insurance_data.py    sales.csv

# %%
# %run Insurance_data.py

# %% [markdown]
# Exploration of our data

# %%
df.head()
#A look at how the first five rows look like in our data
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Number of rows and columns
# Out:
# (1338, 7)

# %%
df.size
# the size of our data
# Out:
# 9366

# %%
df.dtypes
# Data types for the different columns in our data
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.describe()
# Statistical summaries for all the columns with numerical data in our data
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # ***Visualizations***

# %%
draw_pie_chart_showing_the_size_of_each_region()
# A pie chart showing the different contributions in percentatge for the different regions

# %%
plot_a_box_plot_showing_distribution_of_charges_among_smokers()
# According to the box plot below, smokers are charged way higher than non smokers.

# %%
plot_a_bar_plot_showing_charges_per_region()
# The bar graph below shows that southwest pays more insurance charges and northeast pays the least.

# %%
plot_a_box_plot_showing_distribution_of_charges_among_smokers_of_different_sexes()
# The box plot below shows that men smoke more than female and hence pay more insurance charges than the female

# %%
plot_a_bar_plot_showing_smoking_status_and_number_of_charges_per_region()
# The bar graph below agrees with what we have seen earlier on.
# Southeast has more smoker and thus pays way more insurance charges and northeast pays less charges because it has less smokers

# %%
plot_scatter_plot_showing_relationship_between_age_and_charges()
# The scatter plot below shows that there is no relationship between age and insurance charges.

# %%
plot_bar_gragh_showing_smoking_status_and_number_of_charges()
# The bar plot below agrees with what was earlier on seen on the box plot.
# Men smoke more than women and hence are charged more on insurance.
